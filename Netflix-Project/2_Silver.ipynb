# %% [markdown]
# ##**PARAMETERS**

# %%
dbutils.widgets.text("sourcefolder","netflix_directors")
dbutils.widgets.text("targetfolder","netflix_directors")

# %% [markdown]
# ##**VARIABLES TO STORE THE PARAMETER VALUES**

# %%
var_src_folder = dbutils.widgets.get("sourcefolder")
var_tgt_folder = dbutils.widgets.get("targetfolder")

# %% [markdown]
# ##**Silver Notebook Lookup Tables**

# %%
df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load(f"abfss://bronze@netflixazuredatalake.dfs.core.windows.net/{var_src_folder}")

# %%
display(df)

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .option("path",f"abfss://silver@netflixazuredatalake.dfs.core.windows.net/{var_tgt_folder}")\
    .save()
